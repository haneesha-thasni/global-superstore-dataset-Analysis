# %% [markdown]
# <a href="https://colab.research.google.com/github/haneesha-thasni/global-superstore/blob/main/global_superstore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Global Superstore
#
# The Global Superstore dataset is a popular sample dataset often used for data analysis and visualization exercises. It generally includes the following key fields:
#
# Order ID: Unique identifier for each order.
#
# Order Date: Date when the order was placed.
#
# Ship Date: Date when the order was shipped.
#
# Ship Mode: The shipping method used (e.g., Standard Class, Second Class, etc.).
#
# Customer ID: Unique identifier for each customer.
#
# Customer Name: Name of the customer.
#
# Segment: Customer segment (e.g., Consumer, Corporate, Home Office).
#
# Country: Country where the customer is located.
#
# City: City where the customer is located.
#
# State: State where the customer is located.
#
# Postal Code: Postal code of the customer's address.
#
# Category: Product category (e.g., Furniture, Office Supplies, Technology).
#
# Sub-Category: More specific category within the broader category.
#
# Product Name: Name of the product.
#
# Sales: Sales amount for the order.
#
# Quantity: Quantity of products ordered.
#
# Discount: Discount applied to the order.
#
# Profit: Profit made on the order.
#
# This dataset is used to analyze sales performance, customer behavior, and other

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('global_superstore.xlsx')

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
# ...       ...                       ...        ...        ...           ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19      Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10           std
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31  Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21           std
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26  Second Class
#
# ...

# %%
data.shape
# Out:
# (51290, 24)

# %%
data.size
# Out:
# 1230960

# %%
data.head(10)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5   22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 6   30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7   31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 8   40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9   36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# ...

# %%
data.tail(10)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51281    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51282   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51283   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
data.describe().T
# .T - used to transpose
# Out:
#                  count                           mean                  min  \
# Row ID         51290.0                        25645.5                  1.0
# Order Date       51290  2014-05-11 21:26:49.155780608  2012-01-01 00:00:00
# Ship Date        51290  2014-05-15 20:42:42.745174528  2012-01-03 00:00:00
# Postal Code     9994.0                   55190.379428               1040.0
# Sales          51290.0                     246.490581                0.444
# Quantity       51290.0                       3.476545                  1.0
# Discount       51290.0                       0.142908                  0.0
# Profit         51290.0                      28.610982            -6599.978
# Shipping Cost  51290.0                      26.478567                1.002
#
#                                25%                  50%                  75%  \
# Row ID                    12823.25              25645.5             38467.75
# ...

# %%
data.describe(include='all')
# Out:
#              Row ID                  Order ID                     Order Date  \
# count   51290.00000                     51290                          51290
# unique          NaN                     25728                            NaN
# top             NaN  CA-2015-SV20365140-42268                            NaN
# freq            NaN                        14                            NaN
# mean    25645.50000                       NaN  2014-05-11 21:26:49.155780608
# min         1.00000                       NaN            2012-01-01 00:00:00
# 25%     12823.25000                       NaN            2013-06-19 00:00:00
# 50%     25645.50000                       NaN            2014-07-08 00:00:00
# 75%     38467.75000                       NaN            2015-05-22 00:00:00
# max     51290.00000                       NaN            2015-12-31 00:00:00
# std     14806.29199                       NaN                            NaN
#
# ...

# %%
data.describe(include='object')
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2015-SV20365140-42268  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1102            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID         Category  \
# count            51290         51290        51290            51290
# unique              23             5         3788                3
# ...

# %%
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Row ID            51290
# Order ID          25728
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID       17415
# Customer Name       796
# Segment               3
# Postal Code         631
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             27200
# Quantity             14
# Discount             29
# Profit            28234
# Shipping Cost     16753
# Order Priority        4
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
data.value_counts()
# Out:
# Row ID  Order ID                  Order Date  Ship Date   Ship Mode       Customer ID   Customer Name     Segment      Postal Code  City         State          Country        Region       Market  Product ID   Category         Sub-Category  Product Name                                                               Sales    Quantity  Discount  Profit     Shipping Cost  Order Priority
# 31297   CA-2014-CG12520140-41952  2014-11-09  2014-11-12  Second Class    CG-125201408  Claire Gute       Consumer     42420.0      Henderson    Kentucky       United States  Southern US  USCA    FUR-BO-3645  Furniture        Bookcases     Bush Somerset Collection Bookcase                                          261.960  2         0.0        41.9136   54.10          Critical          1
# ...

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# ## **checking duplicates**

# %%
data.duplicated()
# to check duplicate values, display boolean
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
data.duplicated().sum()
# display duplicated number counts
# Out:
# 0

# %%
data.duplicated(subset=['Customer ID','Product ID']).sum()
# to display specific column duplicated numbers
# Out:
# 118

# %%
df1=data[data.duplicated(subset=['Customer ID','Product ID'])]
# store to a new variable specific column duplicates and display

# %%
df1
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 143     31649  CA-2014-AB10060140-41884 2014-09-02 2014-09-04     First Class
# 2628    40081  US-2015-AS10630140-42081 2015-03-18 2015-03-24  Standard Class
# 4257    33490  CA-2014-AP10915140-41984 2014-12-11 2014-12-18  Standard Class
# 4892    10287   US-2014-DN1369018-41688 2014-02-18 2014-02-22  Standard Class
# 5091     2377   MX-2013-AG1090082-41398 2013-05-04 2013-05-09  Standard Class
# ...       ...                       ...        ...        ...             ...
# 50428   10001   US-2014-DP1300018-41909 2014-09-27 2014-10-01  Standard Class
# 50611      11   MX-2014-DP1300018-41909 2014-09-27 2014-10-01  Standard Class
# 50963   38356  CA-2014-WB21850140-41985 2014-12-12 2014-12-12        Same Day
# 51017   10091   US-2012-KT1646518-41017 2012-04-18 2012-04-24  Standard Class
# 51129   37507  CA-2015-YS21880140-42235 2015-08-19 2015-08-26  Standard Class
#
# ...

# %%
df2=data[data.duplicated(subset=['Customer ID','City'])]

# %%
df2
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 8       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 10      36259  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 21      36260  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 34      40976  CA-2013-AH10030140-41635 2013-12-27 2013-12-31  Standard Class
# 50      37425  US-2012-AH10030140-41206 2012-10-24 2012-10-27     First Class
# ...       ...                       ...        ...        ...             ...
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
#
# ...

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data_6 = { 'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Eve', 'Alice'],
        'Age': [24, 27, 22, 24, 29, 24],
      'City': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Chicago', 'New York'] }
df6=pd.DataFrame(data_6)

# %%
df6
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    Alice   24     New York
# 4      Eve   29      Chicago
# 5    Alice   24     New York

# %%
df6.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
df6.drop_duplicates()
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %%
df_f=df6.drop_duplicates(keep='first')
df_f
# delete duplicate items and keep first item
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %%
df_l=df6.drop_duplicates(keep='last')
# delete duplicate items and keep last item

# %%
df_l
# Out:
#       Name  Age         City
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago
# 5    Alice   24     New York

# %%
df_=df6.drop_duplicates(keep=False)
df_
# delete all duplicated items
# Out:
#       Name  Age         City
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %% [markdown]
# ## **convert data type**

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
data['Postal Code']=data['Postal Code'].astype(str)
# covert a data type to another
# here convert float into str

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code               object
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# ## **feature engineering**

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data[['Sales','Quantity']]
# Out:
#           Sales  Quantity
# 0       221.980         2
# 1      3709.395         9
# 2      5175.171         9
# 3      2892.510         5
# 4      2832.960         8
# ...         ...       ...
# 51285    65.100         5
# 51286    16.720         5
# 51287     8.560         2
# 51288    13.440         2
# 51289    61.380         3
#
# [51290 rows x 2 columns]

# %%
data['Total_Order_Value']=data['Sales']*data['Quantity']
# add a new column(feature)into a dataset

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
# Q) Create a feature that calculate the profit margin as a percentage of the total sales?
data['Profit Margin']=(data['Profit']/data['Total_Order_Value']*100)

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
data.drop(columns='Profit Margin',axis=1)
# to delete a column temperarely
# permanantly use-  inplace=True
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# Create a feature that calculates the price of the product after applying the discount.
data['Final_Price']=data['Sales']*1-data['Discount']

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
# create a feature that represents the shipping cost per unit sold
data['Cost_1unit']=data['Shipping Cost']/data['Quantity']

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# ## **extracting date and time components**
# from date time object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
data['order_year']=data['Order Date'].dt.year
# to extract year from 'order date' using datetime module like 2014, 2012,...

# %%
data.head()
# 5 row is default
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...                               Product Name     Sales Quantity Discount  \
# ...

# %%
data['order month']=data['Order Date'].dt.month
data.head()
# to extract month in order date using datetime module like 1,2,6,9...
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Order_Delivery_time oreder_age order_age order_ age Total_Order_Value  \
# ...

# %%
data['order month']=data['Order Date'].dt.month_name()
data.head()
# to extract month name in date format using datetime module like january, february etc..
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Order_Delivery_time oreder_age order_age order_ age Total_Order_Value  \
# ...

# %%
data['Order day']=data['Order Date'].dt.day
# extract day from 'order date' using datetime module like 1,2,3,4,5,6,7
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... oreder_age order_age order_ age Total_Order_Value Profit Margin  \
# ...

# %%
data['order day']=data['Order Date'].dt.day_name()
# extract day name from 'order date' like monday, tuesday.....
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... order_age order_ age Total_Order_Value Profit Margin Final_Price  \
# ...

# %%
data['Ship_year']=data['Ship Date'].dt.year
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... order_ age Total_Order_Value Profit Margin Final_Price  Cost_1unit  \
# ...

# %%
data['Ship_month']=data['Ship Date'].dt.month
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Total_Order_Value Profit Margin Final_Price  Cost_1unit order_year  \
# ...

# %%
data['Ship_month_name']=data['Ship Date'].dt.month_name()
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Profit Margin Final_Price  Cost_1unit order_year order month Order day  \
# ...

# %%
data['Ship_day']=data['Ship Date'].dt.day
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Final_Price  Cost_1unit order_year order month Order day  order day  \
# ...

# %%
data['Ship_day_name']=data['Ship Date'].dt.day_name()
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ...  Cost_1unit order_year order month Order day  order day Ship_year  \
# ...

# %%
# Q) create a new column for the order delivery time difference b/w ship date and order date
data['Order_Delivery_Time']=data['Ship Date']-data['Order Date']
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# **Display today's date**

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2024-08-22 05:49:10.245118

# %%
# Q) Create a feature that calculates the age of an order in days from the order date to today's date
data['Order_ age']=(datetime.datetime.now()-data['Order Date']).dt.days
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
# Q) average shipping delay for orders placed in december
december_orders=data[data['Order Date'].dt.month==12]
december_orders
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# 19      49463   TZ-2015-RH9555129-42343 2015-12-05 2015-12-07    Second Class
# 26      30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 30        220   US-2012-RR1952536-41270 2012-12-27 2012-12-29    Second Class
# 32      40977  CA-2013-AH10030140-41635 2013-12-27 2013-12-31  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51250    8362   MX-2015-BG1169518-42360 2015-12-22 2015-12-24     First Class
# 51254   43851   RS-2015-DP3000108-42355 2015-12-17 2015-12-20    Second Class
# 51263    6367   MX-2012-BP1123082-41264 2012-12-21 2012-12-25  Standard Class
# 51278   10410   ES-2012-LR1703548-41245 2012-12-02 2012-12-02        Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
#
# ...

# %%
avg_shipping_delay=december_orders['Order_Delivery_Time'].mean()
avg_shipping_delay
# Out:
# Timedelta('3 days 22:53:29.333546428')

# %% [markdown]
# ## **replace**

# %%
# Q) replace 'standard class' value in 'ship mode' column with 'std'
data['Ship Mode']=data['Ship Mode'].replace('Standard Class','std')

# %%
data['Ship Mode'].unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'std'], dtype=object)

# %%
# Q) replace 'low' value in 'order priority' column with 'standard'
data['Order Priority'].unique()
# Out:
# array(['High', 'Critical', 'Medium', 'Low'], dtype=object)

# %%
data['Order Priority']=data['Order Priority'].replace('Low','standard')

# %%
data['Order Priority'].unique()
# Out:
# array(['High', 'Critical', 'Medium', 'standard'], dtype=object)

# %% [markdown]
# ## **filter & sort**

# %%
segment_consumer=data[data['Segment']=='Consumer']
segment_consumer.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date    Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13  First Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18  First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06     Same Day
# 6   30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08  First Class
# 7   31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18          std
#
#     Customer ID  Customer Name   Segment  Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman  Consumer      73120.0  Oklahoma City  ...
# 2     CR-127307   Craig Reiter  Consumer          NaN       Brisbane  ...
# 4    RH-9495111    Rick Hansen  Consumer          NaN          Dakar  ...
# 6    TS-2134092  Toby Swindell  Consumer          NaN        Porirua  ...
# 7    MB-1808592     Mick Brown  Consumer          NaN       Hamilton  ...
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# ...

# %%
# Q) filter the rows where profit lessthan zero
data[(data['Profit']<0)]
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 16      39519  CA-2012-AB10015140-40958 2012-02-19 2012-02-25           std
# 30        220   US-2012-RR1952536-41270 2012-12-27 2012-12-29  Second Class
# 40      21316   ID-2014-JB1600059-41873 2014-08-22 2014-08-26           std
# ...       ...                       ...        ...        ...           ...
# 51260   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24           std
# 51266   27081  ID-2013-EK13795102-41496 2013-08-10 2013-08-11   First Class
# 51275   46231    ZA-2012-AS285147-40988 2012-03-20 2012-03-25           std
# 51277   46582   TU-2015-KF6285134-42337 2015-11-29 2015-11-30   First Class
# 51279   43818    NI-2012-PO886595-41159 2012-09-07 2012-09-09  Second Class
#
# ...

# %%
# Q) filter rows where profit is negative and the quantity is greater than 10
filter_rows=data[(data['Profit']<0)&(data['Quantity']>10)]
filter_rows
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 109     11743   IT-2014-VM2168591-41711 2014-03-13 2014-03-13      Same Day
# 289     43395  TU-2013-SF10200134-41417 2013-05-23 2013-05-26   First Class
# 298     16456  IT-2013-JD16060120-41515 2013-08-29 2013-09-01   First Class
# 362     29513   ID-2014-SN2056097-41896 2014-09-14 2014-09-14      Same Day
# 368     29552   IN-2015-SV2078559-42110 2015-04-16 2015-04-18  Second Class
# ...       ...                       ...        ...        ...           ...
# 46367    8903   US-2014-TB2119018-41727 2014-03-29 2014-03-31   First Class
# 48243   32342  CA-2015-SN20710140-42290 2015-10-13 2015-10-17           std
# 49090   19360  IT-2012-MC17590124-41055 2012-05-26 2012-05-29   First Class
# 50328    5131    US-2015-SS208755-42204 2015-07-19 2015-07-23           std
# 50773   40318  CA-2013-VP21760140-41593 2013-11-15 2013-11-20           std
#
# ...

# %%
# Q) calculate the average sales of these filtered rows
filter_rows['Sales'].mean()
# Out:
# 650.2714193333333

# %%
# Q) modify the 'order priority' column to label all orders with a 'profit below zero as "urgent"'?
data.loc[data['Profit']<0,'Order Priority']='Urgent'

# %%
data['Order Priority'].unique()
# Out:
# array(['High', 'Urgent', 'Medium', 'Critical', 'standard'], dtype=object)

# %%
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
# Q) how many rows have 'Urgent' as the order priority
data[data['Order Priority']=='Urgent'].shape[0]
# Out:
# 12544

# %%
# using len()
len(data[data['Order Priority']=='Urgent'])
# Out:
# 12544

# %%
# Q) filter data where category is furniture and profit is greater than 1000
furniture_1000=data[(data['Category']=='Furniture')&(data['Profit']>1000)]
furniture_1000
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 42      25795   IN-2015-VG2180558-42273 2015-09-26 2015-09-28  Second Class
# 66      16653  IT-2015-DK13090120-42345 2015-12-07 2015-12-08   First Class
# 70      21191   IN-2014-AS1022527-41797 2014-06-07 2014-06-09   First Class
# 72      49085    CG-2014-BW106533-41727 2014-03-29 2014-03-31  Second Class
# 88      27962   IN-2014-BK1126011-41940 2014-10-28 2014-10-31   First Class
# 118     14070   IT-2012-ON1871545-40955 2012-02-16 2012-02-19  Second Class
# 190     24859   IN-2015-JF1519021-42341 2015-12-03 2015-12-07           std
# 192     15359  ES-2014-JG15160139-41660 2014-01-21 2014-01-24  Second Class
# 205     15922  ES-2014-RB19570120-41971 2014-11-28 2014-12-04           std
# 243     12449  ES-2015-MS17770139-42275 2015-09-28 2015-10-01   First Class
# 249     50593    EG-2014-MT807038-41675 2014-02-05 2014-02-07  Second Class
# ...

# %%
# Q) filter rows where product name contain word'phone'
data[data['Product Name'].str.contains('Phone')]
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01  Second Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28  Second Class
# 24       1570   US-2015-NP1832582-42216 2015-07-31 2015-08-01   First Class
# ...       ...                       ...        ...        ...           ...
# 50805   31512  CA-2013-VW21775140-41275 2013-01-01 2013-01-08           std
# 50858    8089   US-2015-PS1904598-42349 2015-12-11 2015-12-16           std
# 50881   43296   PL-2012-DB2910103-41005 2012-04-06 2012-04-08  Second Class
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14           std
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31  Second Class
#
# ...

# %% [markdown]
# ## **sorting**

# %%
data['Sales'].sort_values(ascending=False)
# Out:
# 47114    22638.480
# 49003    17499.950
# 44248    13999.960
# 49940    11199.968
# 25238    10499.970
#            ...
# 24977        0.876
# 26588        0.852
# 33493        0.836
# 45391        0.556
# 51260        0.444
# Name: Sales, Length: 51290, dtype: float64

# %%
data[['Sales','Product Name']].sort_values(by='Sales',ascending=False)
# Out:
#            Sales                                       Product Name
# 47114  22638.480  Cisco TelePresence System EX90 Videoconferenci...
# 49003  17499.950              Canon imageCLASS 2200 Advanced Copier
# 44248  13999.960              Canon imageCLASS 2200 Advanced Copier
# 49940  11199.968              Canon imageCLASS 2200 Advanced Copier
# 25238  10499.970              Canon imageCLASS 2200 Advanced Copier
# ...          ...                                                ...
# 24977      0.876                                  Acco 3-Hole Punch
# 26588      0.852                      Avery Round Ring Poly Binders
# 33493      0.836  Avery Durable Slant Ring Binders With Label Ho...
# 45391      0.556           Acco Suede Grain Vinyl Round Ring Binder
# 51260      0.444  Hoover Replacement Belt for Commercial Guardsm...
#
# [51290 rows x 2 columns]

# %%
# Q) sort the dataset first by 'category' in ascending order and then by 'profit' in descending order
data[['Category','Profit']].sort_values(by=['Category','Profit'],ascending=[True,False])
# Out:
#          Category     Profit
# 334     Furniture  2316.5100
# 42      Furniture  2097.0300
# 192     Furniture  2071.4400
# 118     Furniture  1868.1300
# 940     Furniture  1622.8800
# ...           ...        ...
# 362    Technology -3009.4350
# 47527  Technology -3399.9800
# 23110  Technology -3839.9904
# 6591   Technology -4088.3760
# 11755  Technology -6599.9780
#
# [51290 rows x 2 columns]

# %%
# Q) how can you sort the dataset by 'quantity' in descending order and then select the top 10 records
data['Quantity'].sort_values(ascending=False).head(10)
# Out:
# 7971     14
# 17405    14
# 40522    14
# 15388    14
# 33134    14
# 13398    14
# 17675    14
# 10107    14
# 2680     14
# 31397    14
# Name: Quantity, dtype: int64

# %%
# Q) sort the dataset by "order date" in ascending order
data['Order Date'].sort_values(ascending=True)
# Out:
# 22950   2012-01-01
# 43610   2012-01-01
# 25078   2012-01-01
# 31870   2012-01-01
# 31583   2012-01-01
#            ...
# 17379   2015-12-31
# 42870   2015-12-31
# 39873   2015-12-31
# 7908    2015-12-31
# 39602   2015-12-31
# Name: Order Date, Length: 51290, dtype: datetime64[ns]

# %%
# Q) Filter the dataset to include  only rows where the order date is between '2013-01-01' and '2014-12-31'?
data.loc[(data['Order Date']>='2013-01-01')&(data['Order Date']<='2014-12-31')]
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
# ...       ...                       ...        ...        ...           ...
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09      Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31   First Class
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10           std
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21           std
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26  Second Class
#
# ...

# %%
data = { 'Timestamp': ['2024-07-24 14:45:00', '2024-07-25 16:30:00',
                                         '2024-07-26 08:20:00', '2024-07-27 12:15:00'] }
df = pd.DataFrame(data)

# %%
df
# Out:
#              Timestamp
# 0  2024-07-24 14:45:00
# 1  2024-07-25 16:30:00
# 2  2024-07-26 08:20:00
# 3  2024-07-27 12:15:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])
# convert to datetime format
# to_datetime  :- pandas function to convert datetime format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %%
df['Timestamp']=(df['Timestamp']).astype('datetime64[ns]')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %%
df['date']=df['Timestamp'].dt.date
df['year']=df['Timestamp'].dt.year
df['month']=df['Timestamp'].dt.month
df['month_name']=df['Timestamp'].dt.month_name()
df['day']=df['Timestamp'].dt.day
df['day_name']=df['Timestamp'].dt.day_name()

# %%
df['hour']=df['Timestamp'].dt.hour
# to extract hour in time
df['minute']=df['Timestamp'].dt.minute
# to extract minute in time
df['second']=df['Timestamp'].dt.second
# to extract second in time

# %%
df
# Out:
#             Timestamp        date  year  month month_name  day   day_name  \
# 0 2024-07-24 14:45:00  2024-07-24  2024      7       July   24  Wednesday
# 1 2024-07-25 16:30:00  2024-07-25  2024      7       July   25   Thursday
# 2 2024-07-26 08:20:00  2024-07-26  2024      7       July   26     Friday
# 3 2024-07-27 12:15:00  2024-07-27  2024      7       July   27   Saturday
#
#    hour  minute  second
# 0    14      45       0
# 1    16      30       0
# 2     8      20       0
# 3    12      15       0

# %% [markdown]
# **date_range**
#
# To generate a date range in Pandas, you can use the pd.date_range() function. This is useful for creating sequences of dates or for setting up a date index.
#
# You can specify the start date, end date, and frequency of the dates.
#
# Parameters:
# start: The start date of the range.
# end: The end date of the range.
# freq: The frequency of the dates ('D' for daily, 'W' for weekly, 'M' for monthly, etc.).

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01')

# %% [markdown]
# to create a date column with randomly includes starting and ending date

# %%
ds
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01',freq='D')
ds
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01',freq='M')
ds
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %% [markdown]
# 'periods' used for the controlling the frequency

# %%
ds=pd.date_range(start='2020-01-01',end='2021-01-01',periods=10)
ds
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-02-10 16:00:00',
#                '2020-03-22 08:00:00', '2020-05-02 00:00:00',
#                '2020-06-11 16:00:00', '2020-07-22 08:00:00',
#                '2020-09-01 00:00:00', '2020-10-11 16:00:00',
#                '2020-11-21 08:00:00', '2021-01-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)
